# %%
using Random

# %%
rng = MersenneTwister(1234);
p = randperm(rng, 784);
D = randn(784,50_000)
# Out:
# 784×50000 Array{Float64,2}:
#  -0.343683    2.23222     2.94907    …  -1.26161      1.54924    -0.226229
#   0.787115    1.38084    -0.109381      -1.37483     -0.0346193  -1.79482
#  -0.719629    0.686965    0.350127      -0.422813    -1.17095     1.37075
#  -0.297433    0.398796   -0.20351       -0.605582     0.183529    1.02572
#   0.456482   -0.0679975  -1.17272       -0.552587     1.04266     0.584592
#  -0.529885    0.0675561   0.308324   …  -1.85666     -2.20274    -0.308551
#   0.655254    0.872109    1.39605       -0.457564     0.0267303  -0.769821
#  -0.475613   -0.411756    0.0130563     -0.0479374    1.49492    -0.207223
#  -0.387425   -0.0639302  -1.12253       -0.00135464   0.862675    0.402653
#   1.97575     0.298273   -0.786341      -0.473072    -2.03959    -0.482067
#  -1.68722    -1.81875     2.25231    …   2.1568      -0.828802   -0.46575
#  -0.979305   -0.750973   -0.0323375     -2.22005      1.13668    -0.60889
# ...

# %%
for column in eachcol(D)
    permute!(column,p)
end
